# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import re
import random as rand

# %%
# Get 16 random pages from the 72 available
pages = [str(x) for x in rand.sample(range(1,73), 16)]

# %%
# Get 25 stolen items per page from sample
params = [{"pageSize" : "25", "page" : x} for x in pages]
base_url = "https://api.fbi.gov/@artcrimes"
rs = [requests.get(base_url, param) for param in params]

# %%
# Concatenate all json items dicts from sampled pages
thievery = pd.concat([pd.DataFrame(r.json()['items']) for r in rs], ignore_index=True)

# %%
# Keep only columns of interest
thievery = thievery.loc[:,['title', 'maker', 'crimeCategory', 'materials', 'period', 'measurements']]

# %%
# Crime category: standardize description separation method
thievery['crimeCategory'].replace(',', '-', regex=True, inplace=True)

# Special cases 
thievery['crimeCategory'] = np.where(thievery['crimeCategory'] == "dollsandfigurines", "dolls-and-figurines", thievery['crimeCategory'])
thievery['crimeCategory'] = np.where(thievery['crimeCategory'] == "stringinstruments", "string-instruments", thievery['crimeCategory'])

# Check value counts for other special cases (won't worry about converting None to NA)
dict(thievery['crimeCategory'].value_counts())

# %%
# Materials category: standardize to propercase
thievery['materials'] = thievery['materials'].str.title()

# Check that str.title worked, won't change other than that (don't know enough about art)
dict(thievery['materials'].value_counts())

# %%
# Period: group by century when able, move to other category if not

# 1. standardize to lowercase
thievery['period'] = thievery['period'].str.lower()

# 2. take out qualifiers within century (mid, late, early)
thievery['period'] = thievery['period'].str.replace(r'(mid\s)|(late\s)|(early\s)', '', regex=True)

# 3. move misc. and date ranges that cover multiple centuries to other category
# thievery['period'] = np.where

# 4. move years to their respective centuries (treat circa as exact year)
# FOR LOOP OVER CENTURIES

# %%
dict(thievery['period'].value_counts())
# Out:
# {'20th century': 50,
#  '13th century': 6,
#  '18th century': 6,
#  '17th century': 6,
#  '19th century': 5,
#  '1989': 5,
#  '1983': 5,
#  '1986': 5,
#  '1980': 4,
#  '1974': 4,
#  'circa 1935': 4,
#  '1999': 3,
#  '1979': 3,
#  '1977': 3,
#  '1599': 3,
#  '1972': 3,
#  '1940': 3,
#  '1969': 3,
#  '1997': 3,
#  "90's": 3,
#  '1991': 3,
#  '1985': 2,
#  '1600-1800': 2,
#  '1890': 2,
#  '1914': 2,
#  '1950': 2,
#  '1967': 2,
#  '1935': 2,
#  '1971': 2,
#  '2000': 2,
#  '1960': 2,
#  '1950-1970': 2,
#  '1992': 2,
#  '1984': 2,
#  '600 ad': 2,
#  '1990s': 2,
#  '1965-1969': 2,
#  '10 in': 1,
#  '1890-1905': 1,
#  '1954': 1,
#  'modern': 1,
#  '1976': 1,
#  '1970': 1,
#  '1927': 1,
#  '1995-1999': 1,
#  '1855': 1,
#  '1807': 1,
#  '1920s': 1,
#  'pre-classic': 1,
#  '1951': 1,
#  '1996': 1,
#  '1524-1606': 1,
#  'circa 1950': 1,
#  '1650': 1,
#  '1801-1828': 1,
#  '1124': 1,
#  '1829': 1,
#  '1115': 1,
#  '16th-17th century': 1,
#  '1978': 1,
#  'copyright 1985': 1,
#  '1644-1646': 1,
#  'circa 1951': 1,
#  '1612': 1,
#  '1900-1965': 1,
#  '1200-1300': 1,
#  '2008': 1,
#  'prior to 1934': 1,
#  '1906-1907': 1,
#  '1900-1966': 1,
#  '2013': 1,
#  '1900-1935': 1,
#  "1950's": 1,
#  'circa a.d. 1250-1375': 1,
#  'copyright: 1927': 1,
#  '1930': 1,
#  '1533': 1,
#  '1964': 1,
#  '2009': 1,
#  '1953': 1,
#  'circa 1650': 1,
#  'circa 1884': 1,
#  '1926-1927': 1,
#  '2007': 1,
#  '2006': 1,
#  '1890-1944': 1,
#  '1941': 1,
#  '1368-1643': 1,
#  '1910': 1,
#  '1994': 1,
#  '1922': 1,
#  '2010': 1,
#  '1162': 1,
#  '1985-1995': 1,
#  '1982': 1,
#  '1946': 1,
#  'circa 1870': 1,
#  '1665': 1,
#  '1881-1955': 1,
#  '960-1279': 1,
#  '1889': 1,
#  '1346': 1,
#  '1988': 1,
#  '200 b.c.-400 a.d.': 1,
#  '17th-18th c. french or italian baroque': 1,
#  '125-128 a.d.': 1,
#  '1720': 1,
#  '1938': 1,
#  '1610-1690': 1,
#  '1989-1990': 1,
#  '200-400 ad': 1,
#  'copyright: 1668': 1,
#  'copyright: 1882': 1,
#  'circa 1787': 1,
#  'circa 1865': 1,
#  '1900-1969': 1,
#  '2015': 1,
#  'copyright: 1824': 1,
#  '1865-1900': 1,
#  '1850-1899': 1,
#  '1539-1614': 1,
#  '17th-18th century': 1,
#  '1500 to 500 bc': 1,
#  'copyright: 1898': 1,
#  '1814': 1,
#  '1736-1795': 1,
#  '1980s': 1,
#  'copyright: 1922': 1,
#  '1852-1929': 1,
#  'copyright 1841': 1,
#  '1973': 1,
#  '1993': 1,
#  '1637-1650': 1,
#  '1600': 1,
#  '1200': 1,
#  '1844': 1,
#  'copyright: 1971': 1,
#  '1810': 1,
#  'copyright 1697': 1,
#  '1959': 1,
#  '1642-1727': 1,
#  '1916': 1,
#  '1861-1936': 1,
#  '1949': 1,
#  '1733-1737': 1,
#  '1886': 1,
#  '1930s': 1,
#  '1998': 1,
#  '(1) 1796 (2) 1798 (3) 1795-1796 (4) 1796': 1,
#  '1948': 1,
#  '1900-1968': 1,
#  '1936': 1,
#  '1987': 1,
#  '1924-1926': 1,
#  '1853-1902': 1,
#  '1845': 1,
#  'unknown': 1,
#  '1710': 1,
#  '1510-1563': 1,
#  '1870-1890': 1,
#  '1900-1957': 1,
#  '1600-1800 a.d.': 1,
#  '1714': 1,
#  'meiji period: 1852-1912': 1,
#  '1962': 1,
#  'copyright: 1947': 1,
#  '2nd - 3rd century ad': 1,
#  '1885': 1,
#  'copyright: 1932': 1,
#  '1930s, qing dynasty': 1}

# %%
thievery['period'] = np.where(thievery['period'].str.match('.*19\d{2}'), '20th century', thievery['period'])

# %%
thievery['period'] = np.where(thievery['period'].str.match('.*18\d{2}'), '19th century', thievery['period'])

# %%
thievery['period'] = np.where(thievery['period'].str.match('.*20\d{2}'), '21st century', thievery['period'])

# %%
thievery['period'] = np.where(thievery['period'].str.match('.*20\d{2}'), '21st century', thievery['period'])

# %%
thievery.columns
# Out:
# Index(['title', 'maker', 'crimeCategory', 'materials', 'period',
#        'measurements'],
#       dtype='object')

# %%
# Maker: combine unknown and anonymous into one category
thievery['maker'] = np.where(thievery['maker'].str.match('(unknown)|(anon.*?)', flags=re.IGNORECASE), "Unknown", thievery['maker'])

# Check that it worked
dict(thievery['maker'].value_counts())

# %%
# measurements: get size of piece
list(thievery['measurements'])
# Out:
# [None,
#  '30 x 24 in',
#  None,
#  '21 x 30 in',
#  '19 x 24 in',
#  '23 1/8 x 19 1/8 in',
#  '36 x 39 in, frame',
#  '27 x 24 x 9.5 in',
#  'Height: 5 in.; Diameter: 11 in.',
#  '109.20 x 151.20 cm',
#  '22 x 18 in',
#  '20 x 30 in',
#  '4.5 x 5.75 in',
#  '12 in',
#  '41.00 x 28.00 cm',
#  '60.00 x 81.00 cm',
#  '23 7/8 in',
#  '25 x 34 in',
#  '16 x 8 in',
#  '27 x 40 in',
#  None,
#  '4.60 x 2.20 cm',
#  '6 in',
#  '56.50 x 76.30 cm',
#  'Diameter: 3 3/8 in.',
#  '19 x 24 in, frame: 26 x 31 in',
#  '40 x 30 in',
#  '24 x 30 in',
#  None,
#  '21 x 16.5 in',
#  '71.10 x 104.10 cm',
#  '5" height x 4.5" square',
#  '16 x 12 in',
#  '48.5 x 35.75 in',
#  None,
#  'y: 5.25 in',
#  'Height: 30 in; Width: 40 in.',
#  None,
#  None,
#  None,
#  None,
#  '26 x 34 in',
#  '12 x 16 in',
#  '12 x 9 in',
#  '8 x 7 in',
#  '11 x 10 in',
#  None,
#  '83" x 68.5"',
#  '73.75 x 108.12 cm',
#  '21.50 x 13.00 cm',
#  '19.00 cm',
#  '16 x 20 in',
#  'Early 17th Century',
#  None,
#  '26 x 36 in',
#  '26 x 34 in',
#  None,
#  None,
#  '33 x 25 3/16 in',
#  None,
#  '18 in',
#  'Height: 24 cm; Length: 21 cm; Width: 10 cm',
#  'Approximately 60" x 72"',
#  None,
#  '4\' 5"',
#  None,
#  '16 x 23 in',
#  None,
#  '7 x 4 in',
#  '26 x 34 in',
#  '22.30 x 15.00 cm',
#  None,
#  '26.40 x 36.60 cm',
#  None,
#  '80.00 x 40.00 cm',
#  '24.5 in',
#  None,
#  None,
#  '16.5 x 23 in',
#  '19 x 19 in',
#  '31.00 cm',
#  'Length: 9 cm',
#  'Height: 150cm; Width: 100cm',
#  'Diameter: 7 in',
#  'Height: 30"; Width: 25"',
#  '28.5 x 10.5 in',
#  'Panel',
#  None,
#  None,
#  None,
#  '9.25 x 13 in',
#  '13.5 x 9 x 8 in',
#  '37 x 47 in',
#  '18 x 21.5 in',
#  '6 in',
#  '11.5 x 16 in',
#  '28 x 38 in',
#  '22 x 18 in',
#  None,
#  'Length: 26 cm',
#  '80.00 x 60.00 cm',
#  None,
#  None,
#  '145.00 x 170.00 cm',
#  'Height: 19 in; Width: 9 in',
#  'Length: 23 cm',
#  None,
#  '13.00 cm',
#  '11 x 28 in',
#  None,
#  '40.50 x 29.50 cm',
#  'Height: 19.69 in; Width: 16.54 in',
#  '8.70 x 4.30 cm',
#  '13\' x 9\' 2"',
#  'Length: 21 cm',
#  '13.75 x 27 in',
#  '34 x 32 in; Diameter: 26 in; Weight: 45 lbs',
#  '23 x 9 inches',
#  '8 in',
#  '16 x 21.5 in',
#  '17.5 in and 12 in',
#  None,
#  None,
#  '16 in',
#  '14.5 x 9.5 in',
#  None,
#  '18.50 x 11.30 cm',
#  None,
#  '48 x 60 in',
#  'Length of back: 35.3 cm.; Upper Bouts: 16.8 cm.; Middle Bouts: 11.2 cm.; Lower Bouts: 20.4 cm.',
#  '12" x 33" x 15" (43 cm. x 84 cm. x 38 cm.)',
#  'Height: 33.02 cm.; Width: 44.45 cm.',
#  '11 x 16 in',
#  '16 in',
#  '13 x 9.75 in',
#  '60.00 x 90.00 cm',
#  '48.00 x 39.00 cm, y: 68 cm',
#  '24 x 30 in',
#  '30 x 24 in',
#  '16 x 20 in',
#  None,
#  '14 x 16 in',
#  None,
#  '30 x 8 in',
#  '17.5 x 14 in',
#  None,
#  None,
#  None,
#  '24 x 22 in.',
#  '14 x 17 in.',
#  None,
#  '20 x 30 in',
#  '65.00 x 41.00 cm',
#  '37 x 47 in',
#  None,
#  '12 x 17 in',
#  '32 x 42 in',
#  '19.5 x 15.5 in',
#  '36 x 24 in',
#  '20 x 18 in',
#  '30 x 23 in',
#  None,
#  '83" x 68.5"',
#  '23 cm',
#  '6 3/8 x 7 1/2 in',
#  '125.00 x 57.00 cm',
#  '71.00 x 61.00 cm',
#  None,
#  'Height: 6.5 in;  Width: 5 in',
#  None,
#  'Length: 63 in; Width: 66 in; Weight: 180 lbs',
#  None,
#  None,
#  'Height: 10.5 in; Width: 8.25 in',
#  '31.5 in x 47.25 in',
#  None,
#  '14 x 12 in',
#  None,
#  '21.5 in',
#  '60 x 72 in',
#  '43.18 x 22.86 x 20.32 cm',
#  '84.00 cm',
#  '16 x 20 in',
#  '29 x 24 in',
#  'Diameter: (1) 9.5" (2) 9.75" (3) 9.5" (4) 9.75"',
#  '20 x 14 in',
#  '29 7/8 x 22 3/8 in',
#  '14 x 7 in',
#  '7 x 7 in',
#  None,
#  None,
#  None,
#  '16 x 20 in',
#  '16.25 x 12 in',
#  '30 x 24 in',
#  None,
#  'Height: 8 in; Width: 10 in',
#  None,
#  '24 x 24 in',
#  '26 in',
#  '16 x 24 in.',
#  '32 x 25 1/2 in.',
#  '16 x 20 in.',
#  '23 x 17.5 in',
#  '24.10 cm',
#  None,
#  None,
#  '23.5 in',
#  '12 1/4in. x 9 3/8in. (with frame)',
#  '24 x 20 in',
#  '29.75 x 25.25 in',
#  '3 x 12.25 in',
#  '20" x 18"',
#  'Height: 22.70 cm',
#  '60 x 60 in',
#  '5.75 x 8 in',
#  None,
#  '8 x 6 in',
#  'Length: 19 cm',
#  'Length: 15 cm; Width: 13 cm',
#  'Height: 11 in; Width: 10 in',
#  '11 x 14 in',
#  'Height: 11.31 in; Width: 8 in',
#  'Height: 5in; Width: 3 in',
#  '4 in',
#  '22 x 14.5 in',
#  '24 x 20 in',
#  None,
#  None,
#  None,
#  '17 x 25 in',
#  '9.5 x 7 .5 in',
#  '17 x 28in.',
#  '30 x 7.5 x 7.5 in',
#  None,
#  '24 x 36 in',
#  '7.00 x 24.00 cm',
#  'Height: 7 5/8 in;  Base Diameter: 2.5 in; Max Diameter: 3 7/8 in; Rim Diameter: 3.5 in',
#  '23 x 16.5 in',
#  '25 in',
#  '102 x 34 in',
#  'Height: 16.5 in; Width: 12 in; Diameter: 7.5 in; Weight 5.55 lbs',
#  '3 x 5 1/2 x 3/4 in',
#  '24 x 30 in',
#  None,
#  'Width: 43 in; Height: 31 in',
#  '17 in x 13.25 in',
#  'Height: 2 in; Diameter: 1 in',
#  '18 x 32 in',
#  '32 x 44 in',
#  'Height: 4.5in; Width: 5in',
#  "9' x 6'",
#  '15.00 x 65.00 x 15.00 cm',
#  None,
#  '73.12 x 108.12 cm',
#  'Height: 8 in; Width: 10 in',
#  '7.20 cm',
#  '73.75 x 108.12 cm',
#  '8.5" x 10" x 18"',
#  None,
#  '28.00 x 36.00 cm',
#  'Height: 6 in; Rim: 3.75 in',
#  None,
#  '60 x 46 in',
#  None,
#  None,
#  '19" x 28"',
#  '28 x 41 in',
#  'Height: 8.5 in; Diameter: 7.5 in',
#  '20 x 26 in',
#  None,
#  '40.00 x 53.00 cm',
#  '16 in',
#  'Height: 19.63 in; Width: 13.5 in',
#  None,
#  '19 x 25 in',
#  '108 x 156 in',
#  'Height: 29.5 in; Width: 35.5 in',
#  '11.75 x 8.25 in',
#  '23.00 cm',
#  None,
#  '20 x 16 in',
#  '26.50 cm',
#  '24 x 30 in',
#  '13.50 x 5.10 cm',
#  '40 x 27.5 in',
#  None,
#  None,
#  'Length: 12.25 in; Width: 19.75 in',
#  None,
#  '56" x 90"',
#  '28 1/8" x 19"',
#  '15 x 21 in',
#  'Length: 34.5" (approximately); Width: 6" (approximately)',
#  '58" x 29" x 18"',
#  'Height: 9 in; Width: 7 in',
#  None,
#  '28.00 x 24.00 cm',
#  '10 5/8 in',
#  'Diameter: 2.30 cm',
#  '43 x 52 in',
#  None,
#  '6 x 12 in, frame',
#  None,
#  '16.25 in',
#  None,
#  None,
#  '36 x 48 in',
#  '27.5" x 21"',
#  None,
#  '16.25 in',
#  None,
#  None,
#  None,
#  '18 in',
#  '30 x 22 in',
#  None,
#  '24 x 24 in, y: 3 3/8 in',
#  None,
#  '12.00 x 6.80 cm',
#  '16 x 12 in',
#  None,
#  None,
#  '42 x 30 in',
#  '9.5 x 6 in',
#  'Diameter: 2.30 cm',
#  'Length: 74 in; Width: 32 in; Height: 14 in; Weight: 598 lbs.',
#  '44" x 57"',
#  None,
#  '21 in x 17 in',
#  '73.75 x 107.50 cm',
#  '17 x 19 in',
#  None,
#  '43 x 35 in',
#  'Diameter: 5 in',
#  None,
#  None,
#  '8.5 x 11 in',
#  'Diameter of shade: 15"; Diameter of base: 8.5"; Height of base: 18"',
#  '24" x 36"',
#  '3.5 x 2.5 in',
#  '10 x 8 in',
#  '100.00 x 180.00 cm',
#  'Diameter: 2.30 cm',
#  '21.25 x 17.5 in',
#  None,
#  '5.75 x 9 in',
#  '32 x 22.75 in',
#  '47 x 12 x 11.5 in',
#  '73.75 x 108.12 cm',
#  '83.6 grams',
#  None,
#  '7 x 9 in',
#  None,
#  None,
#  None,
#  '105.00 x 68.00 cm',
#  'Width 13.5 in; Height: 10 in',
#  '14 x 11.5 in',
#  None,
#  '21 x 16 in, frame',
#  '12 in',
#  None,
#  'Height: 60 in; Length: 36 in.',
#  '41 1/4 x 29 5/8 in',
#  '42 x 60 in',
#  None,
#  '14 x 11 in',
#  None,
#  'Height: 31 cm; Width: 26.5 cm',
#  '13 in',
#  '104.00 x 54.00 cm',
#  None,
#  '50 x 40 in',
#  None,
#  None,
#  '12 x 14 in',
#  '26 x 20 in',
#  '20 x 20 in',
#  '10 x 12 in',
#  '13 x 12 in',
#  '20 x 29.5 in',
#  '38 x 38 in',
#  '10 x 10 in',
#  'Approximately 7.5 inches maximum width along blade; approximately 14 inches overall length',
#  '24 x 30.5 in',
#  '21.00 cm',
#  '15.5 x 17.125 in',
#  '36 x 22 in',
#  '30 x 19 in',
#  None,
#  '26 x 22 in',
#  '48 x 36 in',
#  'Height: 7.5in; Width: 7in',
#  '11 x 8 in',
#  '12 in',
#  '50 3/8 x 36 3/8 in',
#  'Height: 6.35 cm; Length: 1.65 cm; Width: 1.65 cm',
#  None,
#  '18.5 x 7.5 x 4 in']
